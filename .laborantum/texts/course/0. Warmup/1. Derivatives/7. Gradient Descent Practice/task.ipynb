# %% [markdown]
# # Gradient Descent Practice

# %% [markdown]
# Gradient descent is a core numerical optimization technique used in machine learning. In this practice, we are going to code the gradient descent algorithm and use it on 1D and 2D functions.
#
# It works in exactly the same way for higher-dimensional functions, with the only exception that the process is impossible to visualize directly.

# %%
import numpy as np
import matplotlib.pyplot as plt
import json_tricks

answer = {}

# %% [markdown]
# # Task 1. Code the Gradient Descent Algorithm

# %% [markdown]
# The inputs to your function are:
# - current position $\mathbf x$, `x`
# - gradient of the objective function $\nabla L$, `grad`
# - learning rate $\alpha$
#
# Code the update step of the gradient descent algorithm.

# %%
def grad_descent(x, grad, alpha=0.1):
    res = x
    ## YOUR CODE HERE
    return res

# %% [markdown]
# # Task 2. Code Objective Function

# %% [markdown]
# We will use a super simple objective function:
#
# $f(x) = x^2$
#
# Code this function and its gradient below.

# %%
def f_1d(x):
    res = x**2
    return res

def grad_f_1d(x):
    res = 2 * x
    return res

# %%
position = 5

history = []
for index in range(10):
    grad = grad_f_1d(position)
    position = grad_descent(position, grad)
    history.append(position)

xs = np.linspace(-6, 6, 100)
ys = f_1d(xs)

history = np.array(history)

plt.plot(xs, f_1d(xs), label="Loss function")
plt.plot(history, f_1d(history), 'o', label="Optimization path")
dx = np.diff(history)  # Change in x
dy = np.diff(f_1d(history))       # Change in y
plt.quiver(history[:-1], f_1d(history)[:-1], dx, dy, angles="xy", scale_units="xy", scale=1, color="red", label="Steps")

plt.legend()
plt.title("Optimization Path with Arrows")
plt.show()

answer['1d'] = history.tolist()

# %% [markdown]
# # Task 3. 2D optimization
#
# The simple test case has passed. Let us take a look at a 2D function and how it will be optimized.
#
# In this case we will be optimizing a slightly more sophisticated function:
#
# $f(x, y) = (1 - x)^2 + 10 (y - x^2)^2$
#
# Note that in this case, the input in loss function is a 2D point with coordinates:
#
# ```
# numpy.array([1, 2])
# ```
#
# Write a function that calculates the objective function and its gradient.

# %%
def loss_2d(x):
    res = x.sum()
    ## YOUR CODE HERE
    return res

def loss_2d_grad(x):
    grad = np.zeros_like(x)
    ## YOUR CODE HERE
    return grad

# %%
position = np.array([-1, 0])

history = [position]
for index in range(1000):
    grad = loss_2d_grad(position)
    position = grad_descent(position, grad, alpha=0.02)
    history.append(position)

xs = np.linspace(-2, 2, 400)
ys = np.linspace(-1, 3, 400)

xs, ys = np.meshgrid(xs, ys)

history = np.array(history)

plt.contour(xs, ys, loss_2d(np.stack([xs, ys])), label="Loss function", levels=np.logspace(0, 3, 20))
x, y = history[:, 0], history[:, 1]
dx = np.diff(x)
dy = np.diff(y)
plt.quiver(x[:-1], y[:-1], dx, dy, angles="xy", scale_units="xy", scale=1, color="red", width=0.005)
plt.plot(x, y, 'o', label="Optimization path")

answer['2d'] = history.tolist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 16
#      12 xs, ys = np.meshgrid(xs, ys)
#      13
#      14 history = np.array(history)
#      15
# ---> 16 plt.contour(xs, ys, loss_2d(np.stack([xs, ys])), label="Loss function", levels=np.logspace(0, 3, 20))
#      17 x, y = history[:, 0], history[:, 1]
#      18 dx = np.diff(x)
#      19 dy = np.diff(y)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/pyplot.py:2939, in contour(data, *args, **kwargs)
#    2937 @_copy_docstring_and_deprecators(Axes.contour)
#    2938 def contour(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2939     __ret = gca().contour(
#    2940         *args, **({"data": data} if data is not None else {}), **kwargs
#    2941     )
#    2942     if __ret._A is not None:  # type: ignore[attr-defined]
#    2943         sci(__ret)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6520, in Axes.contour(self, *args, **kwargs)
#    6511 """
#    6512 Plot contour lines.
#    6513
#    (...)   6517 %(contour_doc)s
#    6518 """
#    6519 kwargs['filled'] = False
# -> 6520 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6521 self._request_autoscale_view()
#    6522 return contours
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/contour.py:1589, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1586 z = ma.asarray(z)
#    1588 if z.ndim != 2:
# -> 1589     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1590 if z.shape[0] < 2 or z.shape[1] < 2:
#    1591     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1592                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D

# %% [markdown]
# # Afterword
#
# That is really impressive! We have coded one of the two main algorithms in deep learning: gradient descent!
#
# - How does gradient descent work? Is its behavior logical?
# - Which of the steps can potentially be dangerous?
# - How would you improve gradient descent to avoid that unwanted dangerous step?

# %%
json_tricks.dump(answer, '.answer.json')
